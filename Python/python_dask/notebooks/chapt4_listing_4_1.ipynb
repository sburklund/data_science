# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

fy14 = dd.read_csv('../data/nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv')

fy15 = dd.read_csv('../data/nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2015.csv')

fy16 = dd.read_csv('../data/nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2016.csv')

fy17 = dd.read_csv('../data/nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2017.csv')

# %%
fy14
#fy14.head()
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation Latitude Longitude Community Board Community Council  Census Tract      BIN      BBL      NTA
# npartitions=30
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                   int64            float64              int64           int64       int64         object        int64         object              object           object                            object       object      object              object               int64       int64       object              float64                     object               object             object        object                 int64        int64       object          int64             float64               float64                           float64           float64                  float64  float64   float64         float64            float64      float64  float64  float64  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# Dask Name: from-delayed, 90 tasks

# %%
fy14.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation', 'Latitude', 'Longitude', 'Community Board',
#        'Community Council ', 'Census Tract', 'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
fy15
#fy15.head()
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation Latitude Longitude Community Board Community Council  Census Tract      BIN      BBL      NTA
# npartitions=45
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                  object            float64              int64           int64       int64         object       object         object              object           object                            object       object      object              object              object       int64       object              float64                     object               object             object        object               float64        int64       object          int64              object                object                           float64           float64                  float64  float64   float64         float64            float64      float64  float64  float64  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# Dask Name: from-delayed, 135 tasks

# %%
fy16 
#fy16.head()
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation Latitude Longitude Community Board Community Council  Census Tract      BIN      BBL      NTA
# npartitions=34
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                   int64            float64              int64           int64       int64         object        int64         object              object           object                            object       object      object              object               int64       int64       object              float64                     object               object             object        object               float64        int64       object          int64             float64               float64                           float64           float64                  float64  float64   float64         float64            float64      float64  float64  float64  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...      ...       ...             ...                ...          ...      ...      ...      ...
# Dask Name: from-delayed, 102 tasks

# %%
fy17
#fy17.head()
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=33
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                   int64            float64              int64           int64       int64         object       object         object              object           object                            object       object      object              object               int64       int64       object               object                     object               object             object        object               float64        int64       object          int64              object                object                           float64           float64                  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: from-delayed, 99 tasks

# %%
fy17.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %% [markdown]
# Listing 4.3 Finding the commn columns between the four DataFrames

# %%
# Import for Python 3.x
from functools import reduce

columns = [set(fy14.columns), 
          set(fy15.columns), 
          set(fy16.columns), 
          set(fy17.columns)]

common_columns = list(reduce(lambda a, i: a.intersection(i), columns))
common_columns
# Out:
# ['Time First Observed',
#  'Violation Location',
#  'Violation Time',
#  'Issuing Agency',
#  'Violation County',
#  'No Standing or Stopping Violation',
#  'Violation In Front Of Or Opposite',
#  'Vehicle Make',
#  'Street Code2',
#  'House Number',
#  'Issuer Code',
#  'Vehicle Color',
#  'Days Parking In Effect    ',
#  'Plate Type',
#  'Law Section',
#  'Unregistered Vehicle?',
#  'From Hours In Effect',
#  'Violation Precinct',
#  'Vehicle Expiration Date',
#  'Sub Division',
#  'To Hours In Effect',
#  'Vehicle Body Type',
#  'Vehicle Year',
#  'Street Name',
#  'Intersecting Street',
#  'Date First Observed',
#  'Plate ID',
#  'Violation Post Code',
#  'Issuer Precinct',
#  'Meter Number',
#  'Violation Code',
#  'Registration State',
#  'Violation Description',
#  'Violation Legal Code',
#  'Street Code1',
#  'Double Parking Violation',
#  'Summons Number',
#  'Street Code3',
#  'Issue Date',
#  'Feet From Curb',
#  'Issuer Command',
#  'Hydrant Violation',
#  'Issuer Squad']

# %% [markdown]
# Listing 4.4 Looking at the head of the fy17 DataFrame for the common columns between all data sets

# %%
fy17[common_columns].head()
# Out:
#   Time First Observed  Violation Location Violation Time Issuing Agency  \
# 0                 NaN                 NaN          0143A              V
# 1                 NaN                 NaN          0400P              V
# 2                 NaN                 NaN          0233P              V
# 3                 NaN                14.0          1120A              T
# 4                 NaN                13.0          0555P              T
#
#   Violation County  No Standing or Stopping Violation  \
# 0               BX                                NaN
# 1               BX                                NaN
# 2               BX                                NaN
# 3               NY                                NaN
# 4               NY                                NaN
#
#   Violation In Front Of Or Opposite Vehicle Make  Street Code2 House Number  \
# 0                               NaN        TOYOT             0          NaN
# 1                               NaN        TOYOT             0          NaN
# 2                               NaN         FORD             0          NaN
# 3                                 O        MITSU         34330          330
# 4                                 F        INTER         34310          799
#
#    ...  Violation Legal Code Street Code1 Double Parking Violation  \
# 0  ...                     T            0                      NaN
# 1  ...                     T            0                      NaN
# 2  ...                     T            0                      NaN
# 3  ...                   NaN        10610                      NaN
# 4  ...                   NaN        10510                      NaN
#
#   Summons Number  Street Code3  Issue Date Feet From Curb  Issuer Command  \
# 0     5092469481             0  07/10/2016              0             NaN
# 1     5092451658             0  07/08/2016              0             NaN
# 2     4006265037             0  08/23/2016              0             NaN
# 3     8478629828         34350  06/14/2017              0            T102
# 4     7868300310         34330  11/21/2016              0            T102
#
#    Hydrant Violation Issuer Squad
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN            J
# 4                NaN            M
#
# [5 rows x 43 columns]

# %%
fy14[common_columns].head()
# Out:
# c:\program files\python37\lib\site-packages\dask\core.py:118: DtypeWarning: Columns (18,29,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e5b7d111537f> in <module>()
# ----> 1 fy14[common_columns].head()
#
# c:\program files\python37\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#     897
#     898         if compute:
# --> 899             result = result.compute()
#     900         return result
#     901
#
# c:\program files\python37\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# c:\program files\python37\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     396     keys = [x.__dask_keys__() for x in collections]
#     397     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 398     results = schedule(dsk, keys, **kwargs)
#     399     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     400
#
# c:\program files\python37\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      75                         cache=cache, get_id=_thread_get_id,
# ---> 76                         pack_exception=pack_exception, **kwargs)
#      77
#      78     # Cleanup pools associated to dead threads
#
# c:\program files\python37\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     460                         _execute_task(task, data)  # Re-execute locally
#     461                     else:
# --> 462                         raise_exception(exc, tb)
#     463                 res, worker_id = loads(res_info)
#     464                 state['cache'][key] = res
#
# c:\program files\python37\lib\site-packages\dask\compatibility.py in reraise(exc, tb)
#     110         if exc.__traceback__ is not tb:
#     111             raise exc.with_traceback(tb)
# --> 112         raise exc
#     113
#     114     import pickle as cPickle
#
# c:\program files\python37\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     228     try:
#     229         task, data = loads(task_info)
# --> 230         result = _execute_task(task, data)
#     231         id = get_id()
#     232         result = dumps((result, id))
#
# c:\program files\python37\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# c:\program files\python37\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     117         func, args = arg[0], arg[1:]
#     118         args2 = [_execute_task(a, cache) for a in args]
# --> 119         return func(*args2)
#     120     elif not ishashable(arg):
#     121         return arg
#
# c:\program files\python37\lib\site-packages\dask\compatibility.py in apply(func, args, kwargs)
#      91     def apply(func, args, kwargs=None):
#      92         if kwargs:
# ---> 93             return func(*args, **kwargs)
#      94         else:
#      95             return func(*args)
#
# c:\program files\python37\lib\site-packages\dask\dataframe\io\csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#      56     df = reader(bio, **kwargs)
#      57     if dtypes:
# ---> 58         coerce_dtypes(df, dtypes)
#      59
#      60     if enforce and columns and (list(df.columns) != list(columns)):
#
# c:\program files\python37\lib\site-packages\dask\dataframe\io\csv.py in coerce_dtypes(df, dtypes)
#     151         msg = ("Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.\n\n"
#     152                "%s" % (rule.join(filter(None, [dtype_msg, date_msg]))))
# --> 153         raise ValueError(msg)
#     154
#     155
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +-----------------------+---------+----------+
# | Column                | Found   | Expected |
# +-----------------------+---------+----------+
# | Issuer Squad          | object  | int64    |
# | Unregistered Vehicle? | float64 | int64    |
# | Violation Description | object  | float64  |
# | Violation Legal Code  | object  | float64  |
# | Violation Post Code   | object  | float64  |
# +-----------------------+---------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Issuer Squad
#   ValueError('cannot convert float NaN to integer')
# - Violation Description
#   ValueError("could not convert string to float: 'BUS LANE VIOLATION'")
# - Violation Legal Code
#   ValueError("could not convert string to float: 'T'")
# - Violation Post Code
#   ValueError("could not convert string to float: 'H -'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Issuer Squad': 'object',
#        'Unregistered Vehicle?': 'float64',
#        'Violation Description': 'object',
#        'Violation Legal Code': 'object',
#        'Violation Post Code': 'object'}
#
# to the call to `read_csv`/`read_table`.
